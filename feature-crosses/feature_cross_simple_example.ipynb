# %% [markdown]
# Example taken from Google ML Crash Course:
# https://developers.google.com/machine-learning/crash-course/feature-crosses/encoding-nonlinearity

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

import tensorflow as tf 

pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# pd.show_versions()

# %% [markdown]
# ## Linear Problem

# %% [markdown]
# ### Create the DataSet

# %% [markdown]
# 50 data points per category

# %%
N = 50

# %% [markdown]
# Create the random data set for sick trees
#
# Scale and shift the (0, 1) range from np.random.random to (-5, 5) respectively (0, 5)
#
# See also here: https://stackoverflow.com/questions/59389241/how-to-generate-a-random-float-in-range-1-1-using-numpy-random-rand

# %%
max_x, min_x = 5, -5
range_size = (max_x - min_x)
sick_x = np.random.random([N]) * range_size + min_x

max_y, min_y = 0, -5
range_size = (max_y - min_y)
sick_y = np.random.random([N]) * range_size + min_y

# %% [markdown]
# Create the randomn data set for healthy trees

# %%
max_x, min_x = 5, -5
range_size = (max_x - min_x)
healthy_x = np.random.random([N]) * range_size + min_x

max_y, min_y = 5, 0
range_size = (max_y - min_y)
healthy_y = np.random.random([N]) * range_size + min_y

# %% [markdown]
# Plot the data

# %%
plt.figure(figsize=(10, 8))

plt.scatter(sick_x, sick_y)
plt.scatter(healthy_x, healthy_y)

plt.xlabel('x') 
plt.ylabel('y') 

plt.title("Training Data") 
plt.show()

# %% [markdown]
# Create the Pandas DataFrame

# %%
# combine the x and y arrays
sick_trees = np.vstack((sick_x, sick_y)).T
healthy_trees = np.vstack((healthy_x, healthy_y)).T

data_column_names = ['x', 'y']

df_sick = pd.DataFrame(data=sick_trees, columns=data_column_names)
df_sick['status'] = 1

df_healthy = pd.DataFrame(data=healthy_trees, columns=data_column_names)
df_healthy['status'] = 0

# append is deprecated since pandas 1.4.0
# train_df = df_sick.append(df_healthy, ignore_index=True)
train_df = pd.concat([df_sick, df_healthy], ignore_index=True)

# Shuffle the examples.
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index)) 
shuffled_train_df.head(100)

# Print the entire DataFrame
# print(df)
# Out:
#       x    y  status
# 69 -0.2  2.5       0
# 84  4.3  1.0       0
# 14  0.1 -4.8       1
# 46 -4.1 -4.0       1
# 31  3.8 -4.3       1
# ..  ...  ...     ...
# 91 -3.3  1.4       0
# 24 -0.3 -2.3       1
# 78 -0.6  0.5       0
# 77  2.7  1.1       0
# 9   4.0 -1.2       1
#
# [100 rows x 3 columns]

# %% [markdown]
# Build and Train Model Functions

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(2,), activation = 'sigmoid'))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model               


def train_model(model, x, y, my_epochs, 
                my_batch_size=None, my_validation_split=0.1):
  """Feed a dataset into the model in order to train it."""

  history = model.fit(x=x,
                      y=y,
                      batch_size=my_batch_size,
                      epochs=my_epochs,
                      validation_split=my_validation_split)

  # Gather the model's trained weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
  epochs = history.epoch
  
  # Isolate the root mean squared error for each epoch.
  hist = pd.DataFrame(history.history)
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse, history.history   

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %% [markdown]
# Define plotting functions

# %%
#@title Define the plotting function

def plot_the_loss_curve(epochs, mae_training, mae_validation):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs[1:], mae_training[1:], label="Training Loss")
  plt.plot(epochs[1:], mae_validation[1:], label="Validation Loss")
  plt.legend()
  
  # We're not going to plot the first epoch, since the loss on the first epoch
  # is often substantially greater than the loss for other epochs.
  merged_mae_lists = mae_training[1:] + mae_validation[1:]
  highest_loss = max(merged_mae_lists)
  lowest_loss = min(merged_mae_lists)
  delta = highest_loss - lowest_loss
  print(delta)

  top_of_y_axis = highest_loss + (delta * 0.05)
  bottom_of_y_axis = lowest_loss - (delta * 0.05)
   
  plt.ylim([bottom_of_y_axis, top_of_y_axis])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %% [markdown]
# ### Train

# %%
# The following variables are the hyperparameters.
learning_rate = 0.001
epochs = 1000
batch_size = 10

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse, history = train_model(my_model, 
                                        shuffled_train_df.drop('status', axis=1),
                                        shuffled_train_df[['status']],
                                        epochs, batch_size)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])

# print(weight)
print("\nThe learned weight for your model is: x1 = %.4f, x2 = %.4f" % (weight[0], weight[1]))
print("The learned bias for your model is %.4f\n" % bias )
# Out:
# Epoch 1/1000
# /usr/local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5499 - accuracy: 0.3667 - val_loss: 0.5320 - val_accuracy: 0.4000
# Epoch 2/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5472 - accuracy: 0.3667 - val_loss: 0.5306 - val_accuracy: 0.4000
# Epoch 3/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5451 - accuracy: 0.3667 - val_loss: 0.5294 - val_accuracy: 0.4000
# Epoch 4/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5431 - accuracy: 0.3667 - val_loss: 0.5282 - val_accuracy: 0.4000
# Epoch 5/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5412 - accuracy: 0.3667 - val_loss: 0.5270 - val_accuracy: 0.4000
# Epoch 6/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5392 - accuracy: 0.3667 - val_loss: 0.5259 - val_accuracy: 0.4000
# Epoch 7/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5374 - accuracy: 0.3667 - val_loss: 0.5248 - val_accuracy: 0.4000
# Epoch 8/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5357 - accuracy: 0.3667 - val_loss: 0.5237 - val_accuracy: 0.4000
# Epoch 9/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5339 - accuracy: 0.3667 - val_loss: 0.5227 - val_accuracy: 0.4000
# Epoch 10/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5321 - accuracy: 0.3667 - val_loss: 0.5215 - val_accuracy: 0.4000
# Epoch 11/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5303 - accuracy: 0.3667 - val_loss: 0.5204 - val_accuracy: 0.4000
# Epoch 12/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5285 - accuracy: 0.3667 - val_loss: 0.5194 - val_accuracy: 0.4000
# Epoch 13/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5268 - accuracy: 0.3667 - val_loss: 0.5184 - val_accuracy: 0.4000
# Epoch 14/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5251 - accuracy: 0.3778 - val_loss: 0.5173 - val_accuracy: 0.4000
# Epoch 15/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5233 - accuracy: 0.3778 - val_loss: 0.5163 - val_accuracy: 0.4000
# Epoch 16/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5216 - accuracy: 0.3778 - val_loss: 0.5153 - val_accuracy: 0.4000
# Epoch 17/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5199 - accuracy: 0.3889 - val_loss: 0.5143 - val_accuracy: 0.4000
# Epoch 18/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5183 - accuracy: 0.3889 - val_loss: 0.5133 - val_accuracy: 0.4000
# Epoch 19/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5166 - accuracy: 0.3889 - val_loss: 0.5123 - val_accuracy: 0.4000
# Epoch 20/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5150 - accuracy: 0.3889 - val_loss: 0.5113 - val_accuracy: 0.4000
# Epoch 21/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5134 - accuracy: 0.3889 - val_loss: 0.5103 - val_accuracy: 0.4000
# Epoch 22/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5119 - accuracy: 0.3889 - val_loss: 0.5095 - val_accuracy: 0.4000
# Epoch 23/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5104 - accuracy: 0.3889 - val_loss: 0.5085 - val_accuracy: 0.4000
# Epoch 24/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5088 - accuracy: 0.3889 - val_loss: 0.5075 - val_accuracy: 0.4000
# Epoch 25/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.3889 - val_loss: 0.5065 - val_accuracy: 0.4000
# Epoch 26/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5056 - accuracy: 0.3889 - val_loss: 0.5056 - val_accuracy: 0.4000
# Epoch 27/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5040 - accuracy: 0.3889 - val_loss: 0.5046 - val_accuracy: 0.4000
# Epoch 28/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5024 - accuracy: 0.3889 - val_loss: 0.5036 - val_accuracy: 0.4000
# Epoch 29/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5008 - accuracy: 0.3889 - val_loss: 0.5026 - val_accuracy: 0.4000
# Epoch 30/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4992 - accuracy: 0.4000 - val_loss: 0.5017 - val_accuracy: 0.4000
# Epoch 31/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4976 - accuracy: 0.4000 - val_loss: 0.5007 - val_accuracy: 0.4000
# Epoch 32/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.4000 - val_loss: 0.4997 - val_accuracy: 0.4000
# Epoch 33/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4945 - accuracy: 0.4000 - val_loss: 0.4987 - val_accuracy: 0.4000
# Epoch 34/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4929 - accuracy: 0.4000 - val_loss: 0.4978 - val_accuracy: 0.4000
# Epoch 35/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4914 - accuracy: 0.4111 - val_loss: 0.4968 - val_accuracy: 0.4000
# Epoch 36/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4898 - accuracy: 0.4222 - val_loss: 0.4958 - val_accuracy: 0.4000
# Epoch 37/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4883 - accuracy: 0.4222 - val_loss: 0.4948 - val_accuracy: 0.4000
# Epoch 38/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4867 - accuracy: 0.4333 - val_loss: 0.4938 - val_accuracy: 0.4000
# Epoch 39/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4851 - accuracy: 0.4333 - val_loss: 0.4928 - val_accuracy: 0.4000
# Epoch 40/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4835 - accuracy: 0.4444 - val_loss: 0.4918 - val_accuracy: 0.4000
# Epoch 41/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4819 - accuracy: 0.4556 - val_loss: 0.4908 - val_accuracy: 0.4000
# Epoch 42/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4804 - accuracy: 0.4556 - val_loss: 0.4898 - val_accuracy: 0.4000
# Epoch 43/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4789 - accuracy: 0.4556 - val_loss: 0.4888 - val_accuracy: 0.4000
# Epoch 44/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4774 - accuracy: 0.4556 - val_loss: 0.4878 - val_accuracy: 0.4000
# Epoch 45/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4758 - accuracy: 0.4556 - val_loss: 0.4867 - val_accuracy: 0.4000
# Epoch 46/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4743 - accuracy: 0.4667 - val_loss: 0.4857 - val_accuracy: 0.4000
# Epoch 47/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4727 - accuracy: 0.4667 - val_loss: 0.4846 - val_accuracy: 0.4000
# Epoch 48/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4712 - accuracy: 0.4667 - val_loss: 0.4836 - val_accuracy: 0.4000
# Epoch 49/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4697 - accuracy: 0.4667 - val_loss: 0.4826 - val_accuracy: 0.4000
# Epoch 50/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4682 - accuracy: 0.4667 - val_loss: 0.4815 - val_accuracy: 0.4000
# Epoch 51/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4666 - accuracy: 0.4667 - val_loss: 0.4804 - val_accuracy: 0.4000
# Epoch 52/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4651 - accuracy: 0.4667 - val_loss: 0.4792 - val_accuracy: 0.4000
# Epoch 53/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4634 - accuracy: 0.4667 - val_loss: 0.4780 - val_accuracy: 0.4000
# Epoch 54/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4618 - accuracy: 0.4667 - val_loss: 0.4769 - val_accuracy: 0.4000
# Epoch 55/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4602 - accuracy: 0.4667 - val_loss: 0.4757 - val_accuracy: 0.4000
# Epoch 56/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4586 - accuracy: 0.4667 - val_loss: 0.4745 - val_accuracy: 0.4000
# Epoch 57/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4570 - accuracy: 0.4667 - val_loss: 0.4733 - val_accuracy: 0.4000
# Epoch 58/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4553 - accuracy: 0.4667 - val_loss: 0.4721 - val_accuracy: 0.4000
# Epoch 59/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4537 - accuracy: 0.4667 - val_loss: 0.4708 - val_accuracy: 0.4000
# Epoch 60/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4521 - accuracy: 0.4667 - val_loss: 0.4695 - val_accuracy: 0.4000
# Epoch 61/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4504 - accuracy: 0.4667 - val_loss: 0.4682 - val_accuracy: 0.4000
# Epoch 62/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4487 - accuracy: 0.4667 - val_loss: 0.4669 - val_accuracy: 0.4000
# Epoch 63/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4472 - accuracy: 0.4667 - val_loss: 0.4658 - val_accuracy: 0.4000
# Epoch 64/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4456 - accuracy: 0.4778 - val_loss: 0.4644 - val_accuracy: 0.4000
# Epoch 65/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4438 - accuracy: 0.4778 - val_loss: 0.4631 - val_accuracy: 0.4000
# Epoch 66/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4421 - accuracy: 0.4778 - val_loss: 0.4616 - val_accuracy: 0.4000
# Epoch 67/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4403 - accuracy: 0.4778 - val_loss: 0.4601 - val_accuracy: 0.4000
# Epoch 68/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4385 - accuracy: 0.4778 - val_loss: 0.4586 - val_accuracy: 0.4000
# Epoch 69/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4367 - accuracy: 0.4778 - val_loss: 0.4571 - val_accuracy: 0.4000
# Epoch 70/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4349 - accuracy: 0.4778 - val_loss: 0.4556 - val_accuracy: 0.4000
# Epoch 71/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4331 - accuracy: 0.4778 - val_loss: 0.4540 - val_accuracy: 0.4000
# Epoch 72/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4313 - accuracy: 0.4778 - val_loss: 0.4525 - val_accuracy: 0.4000
# Epoch 73/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4295 - accuracy: 0.4778 - val_loss: 0.4509 - val_accuracy: 0.4000
# Epoch 74/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4276 - accuracy: 0.4778 - val_loss: 0.4492 - val_accuracy: 0.4000
# Epoch 75/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4256 - accuracy: 0.4778 - val_loss: 0.4474 - val_accuracy: 0.4000
# Epoch 76/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4236 - accuracy: 0.4778 - val_loss: 0.4457 - val_accuracy: 0.4000
# Epoch 77/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4215 - accuracy: 0.4778 - val_loss: 0.4438 - val_accuracy: 0.4000
# Epoch 78/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4196 - accuracy: 0.4778 - val_loss: 0.4421 - val_accuracy: 0.4000
# Epoch 79/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4176 - accuracy: 0.4778 - val_loss: 0.4402 - val_accuracy: 0.4000
# Epoch 80/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4155 - accuracy: 0.4778 - val_loss: 0.4383 - val_accuracy: 0.4000
# Epoch 81/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4133 - accuracy: 0.4778 - val_loss: 0.4363 - val_accuracy: 0.5000
# Epoch 82/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4111 - accuracy: 0.4778 - val_loss: 0.4344 - val_accuracy: 0.5000
# Epoch 83/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4091 - accuracy: 0.4778 - val_loss: 0.4324 - val_accuracy: 0.5000
# Epoch 84/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4069 - accuracy: 0.4778 - val_loss: 0.4305 - val_accuracy: 0.5000
# Epoch 85/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4047 - accuracy: 0.4778 - val_loss: 0.4284 - val_accuracy: 0.5000
# Epoch 86/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4024 - accuracy: 0.4778 - val_loss: 0.4262 - val_accuracy: 0.5000
# Epoch 87/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4002 - accuracy: 0.4778 - val_loss: 0.4241 - val_accuracy: 0.5000
# Epoch 88/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3979 - accuracy: 0.4778 - val_loss: 0.4219 - val_accuracy: 0.5000
# Epoch 89/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3957 - accuracy: 0.4778 - val_loss: 0.4197 - val_accuracy: 0.5000
# Epoch 90/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3934 - accuracy: 0.4778 - val_loss: 0.4175 - val_accuracy: 0.5000
# Epoch 91/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3911 - accuracy: 0.4778 - val_loss: 0.4152 - val_accuracy: 0.5000
# Epoch 92/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3887 - accuracy: 0.4778 - val_loss: 0.4130 - val_accuracy: 0.5000
# Epoch 93/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3864 - accuracy: 0.4778 - val_loss: 0.4107 - val_accuracy: 0.5000
# Epoch 94/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3841 - accuracy: 0.4889 - val_loss: 0.4085 - val_accuracy: 0.5000
# Epoch 95/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3818 - accuracy: 0.5000 - val_loss: 0.4060 - val_accuracy: 0.5000
# Epoch 96/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3793 - accuracy: 0.5000 - val_loss: 0.4036 - val_accuracy: 0.5000
# Epoch 97/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3768 - accuracy: 0.5000 - val_loss: 0.4011 - val_accuracy: 0.5000
# Epoch 98/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3743 - accuracy: 0.5111 - val_loss: 0.3986 - val_accuracy: 0.5000
# Epoch 99/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3717 - accuracy: 0.5111 - val_loss: 0.3960 - val_accuracy: 0.5000
# Epoch 100/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3691 - accuracy: 0.5111 - val_loss: 0.3933 - val_accuracy: 0.5000
# Epoch 101/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3664 - accuracy: 0.5111 - val_loss: 0.3907 - val_accuracy: 0.5000
# Epoch 102/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3638 - accuracy: 0.5111 - val_loss: 0.3881 - val_accuracy: 0.5000
# Epoch 103/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3613 - accuracy: 0.5222 - val_loss: 0.3856 - val_accuracy: 0.5000
# Epoch 104/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3587 - accuracy: 0.5222 - val_loss: 0.3830 - val_accuracy: 0.5000
# Epoch 105/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3562 - accuracy: 0.5333 - val_loss: 0.3804 - val_accuracy: 0.5000
# Epoch 106/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3534 - accuracy: 0.5444 - val_loss: 0.3776 - val_accuracy: 0.5000
# Epoch 107/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3508 - accuracy: 0.5444 - val_loss: 0.3749 - val_accuracy: 0.5000
# Epoch 108/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3480 - accuracy: 0.5444 - val_loss: 0.3720 - val_accuracy: 0.5000
# Epoch 109/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3450 - accuracy: 0.5444 - val_loss: 0.3690 - val_accuracy: 0.5000
# Epoch 110/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3422 - accuracy: 0.5444 - val_loss: 0.3663 - val_accuracy: 0.5000
# Epoch 111/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3393 - accuracy: 0.5444 - val_loss: 0.3634 - val_accuracy: 0.5000
# Epoch 112/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3365 - accuracy: 0.5556 - val_loss: 0.3606 - val_accuracy: 0.5000
# Epoch 113/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3335 - accuracy: 0.5556 - val_loss: 0.3576 - val_accuracy: 0.5000
# Epoch 114/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3305 - accuracy: 0.5556 - val_loss: 0.3546 - val_accuracy: 0.5000
# Epoch 115/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3274 - accuracy: 0.5556 - val_loss: 0.3515 - val_accuracy: 0.5000
# Epoch 116/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3243 - accuracy: 0.5556 - val_loss: 0.3486 - val_accuracy: 0.5000
# Epoch 117/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.5667 - val_loss: 0.3455 - val_accuracy: 0.5000
# Epoch 118/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3181 - accuracy: 0.5667 - val_loss: 0.3426 - val_accuracy: 0.5000
# Epoch 119/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3150 - accuracy: 0.5667 - val_loss: 0.3395 - val_accuracy: 0.5000
# Epoch 120/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3117 - accuracy: 0.5667 - val_loss: 0.3364 - val_accuracy: 0.5000
# Epoch 121/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3085 - accuracy: 0.5667 - val_loss: 0.3333 - val_accuracy: 0.5000
# Epoch 122/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3052 - accuracy: 0.5778 - val_loss: 0.3302 - val_accuracy: 0.5000
# Epoch 123/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3020 - accuracy: 0.5778 - val_loss: 0.3273 - val_accuracy: 0.5000
# Epoch 124/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2987 - accuracy: 0.5778 - val_loss: 0.3242 - val_accuracy: 0.5000
# Epoch 125/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2954 - accuracy: 0.5889 - val_loss: 0.3212 - val_accuracy: 0.5000
# Epoch 126/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2920 - accuracy: 0.6000 - val_loss: 0.3181 - val_accuracy: 0.5000
# Epoch 127/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2886 - accuracy: 0.6000 - val_loss: 0.3151 - val_accuracy: 0.6000
# Epoch 128/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2851 - accuracy: 0.6000 - val_loss: 0.3120 - val_accuracy: 0.6000
# Epoch 129/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2817 - accuracy: 0.6000 - val_loss: 0.3090 - val_accuracy: 0.6000
# Epoch 130/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2783 - accuracy: 0.6000 - val_loss: 0.3060 - val_accuracy: 0.6000
# Epoch 131/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2749 - accuracy: 0.6000 - val_loss: 0.3031 - val_accuracy: 0.6000
# Epoch 132/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2714 - accuracy: 0.6000 - val_loss: 0.3000 - val_accuracy: 0.6000
# Epoch 133/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2679 - accuracy: 0.6000 - val_loss: 0.2969 - val_accuracy: 0.6000
# Epoch 134/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2642 - accuracy: 0.6111 - val_loss: 0.2938 - val_accuracy: 0.6000
# Epoch 135/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2606 - accuracy: 0.6222 - val_loss: 0.2907 - val_accuracy: 0.6000
# Epoch 136/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2568 - accuracy: 0.6222 - val_loss: 0.2876 - val_accuracy: 0.6000
# Epoch 137/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2532 - accuracy: 0.6222 - val_loss: 0.2845 - val_accuracy: 0.6000
# Epoch 138/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2495 - accuracy: 0.6222 - val_loss: 0.2815 - val_accuracy: 0.6000
# Epoch 139/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2458 - accuracy: 0.6444 - val_loss: 0.2784 - val_accuracy: 0.6000
# Epoch 140/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2421 - accuracy: 0.6667 - val_loss: 0.2754 - val_accuracy: 0.6000
# Epoch 141/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2384 - accuracy: 0.6667 - val_loss: 0.2723 - val_accuracy: 0.6000
# Epoch 142/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2346 - accuracy: 0.6667 - val_loss: 0.2692 - val_accuracy: 0.6000
# Epoch 143/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2307 - accuracy: 0.6667 - val_loss: 0.2661 - val_accuracy: 0.6000
# Epoch 144/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2267 - accuracy: 0.6667 - val_loss: 0.2629 - val_accuracy: 0.6000
# Epoch 145/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2228 - accuracy: 0.6778 - val_loss: 0.2598 - val_accuracy: 0.6000
# Epoch 146/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2191 - accuracy: 0.6889 - val_loss: 0.2569 - val_accuracy: 0.6000
# Epoch 147/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2154 - accuracy: 0.6889 - val_loss: 0.2540 - val_accuracy: 0.6000
# Epoch 148/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2117 - accuracy: 0.6889 - val_loss: 0.2509 - val_accuracy: 0.6000
# Epoch 149/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2081 - accuracy: 0.6889 - val_loss: 0.2481 - val_accuracy: 0.6000
# Epoch 150/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2044 - accuracy: 0.7000 - val_loss: 0.2452 - val_accuracy: 0.6000
# Epoch 151/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2007 - accuracy: 0.7000 - val_loss: 0.2421 - val_accuracy: 0.6000
# Epoch 152/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1967 - accuracy: 0.7111 - val_loss: 0.2389 - val_accuracy: 0.6000
# Epoch 153/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1928 - accuracy: 0.7222 - val_loss: 0.2358 - val_accuracy: 0.6000
# Epoch 154/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1890 - accuracy: 0.7222 - val_loss: 0.2326 - val_accuracy: 0.6000
# Epoch 155/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1851 - accuracy: 0.7222 - val_loss: 0.2294 - val_accuracy: 0.6000
# Epoch 156/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1816 - accuracy: 0.7222 - val_loss: 0.2266 - val_accuracy: 0.6000
# Epoch 157/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1780 - accuracy: 0.7222 - val_loss: 0.2235 - val_accuracy: 0.6000
# Epoch 158/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1743 - accuracy: 0.7333 - val_loss: 0.2203 - val_accuracy: 0.6000
# Epoch 159/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1705 - accuracy: 0.7333 - val_loss: 0.2171 - val_accuracy: 0.6000
# Epoch 160/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.7444 - val_loss: 0.2140 - val_accuracy: 0.6000
# Epoch 161/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.7444 - val_loss: 0.2108 - val_accuracy: 0.6000
# Epoch 162/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1597 - accuracy: 0.7444 - val_loss: 0.2076 - val_accuracy: 0.6000
# Epoch 163/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1561 - accuracy: 0.7778 - val_loss: 0.2044 - val_accuracy: 0.7000
# Epoch 164/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1526 - accuracy: 0.7778 - val_loss: 0.2012 - val_accuracy: 0.7000
# Epoch 165/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1493 - accuracy: 0.8000 - val_loss: 0.1981 - val_accuracy: 0.7000
# Epoch 166/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.8000 - val_loss: 0.1948 - val_accuracy: 0.7000
# Epoch 167/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1425 - accuracy: 0.8111 - val_loss: 0.1916 - val_accuracy: 0.7000
# Epoch 168/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1392 - accuracy: 0.8222 - val_loss: 0.1883 - val_accuracy: 0.7000
# Epoch 169/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1360 - accuracy: 0.8333 - val_loss: 0.1851 - val_accuracy: 0.7000
# Epoch 170/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1329 - accuracy: 0.8333 - val_loss: 0.1821 - val_accuracy: 0.7000
# Epoch 171/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.8333 - val_loss: 0.1790 - val_accuracy: 0.7000
# Epoch 172/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1271 - accuracy: 0.8333 - val_loss: 0.1760 - val_accuracy: 0.7000
# Epoch 173/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1242 - accuracy: 0.8333 - val_loss: 0.1728 - val_accuracy: 0.7000
# Epoch 174/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.8444 - val_loss: 0.1698 - val_accuracy: 0.7000
# Epoch 175/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1186 - accuracy: 0.8444 - val_loss: 0.1666 - val_accuracy: 0.7000
# Epoch 176/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.8444 - val_loss: 0.1633 - val_accuracy: 0.7000
# Epoch 177/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1131 - accuracy: 0.8444 - val_loss: 0.1602 - val_accuracy: 0.7000
# Epoch 178/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1105 - accuracy: 0.8444 - val_loss: 0.1571 - val_accuracy: 0.7000
# Epoch 179/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.8556 - val_loss: 0.1539 - val_accuracy: 0.7000
# Epoch 180/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1054 - accuracy: 0.8556 - val_loss: 0.1507 - val_accuracy: 0.7000
# Epoch 181/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1030 - accuracy: 0.8556 - val_loss: 0.1477 - val_accuracy: 0.7000
# Epoch 182/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1005 - accuracy: 0.8556 - val_loss: 0.1444 - val_accuracy: 0.7000
# Epoch 183/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.8667 - val_loss: 0.1413 - val_accuracy: 0.7000
# Epoch 184/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0958 - accuracy: 0.8667 - val_loss: 0.1382 - val_accuracy: 0.8000
# Epoch 185/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0937 - accuracy: 0.8667 - val_loss: 0.1353 - val_accuracy: 0.8000
# Epoch 186/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0916 - accuracy: 0.8667 - val_loss: 0.1323 - val_accuracy: 0.8000
# Epoch 187/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0896 - accuracy: 0.8667 - val_loss: 0.1296 - val_accuracy: 0.8000
# Epoch 188/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0877 - accuracy: 0.8667 - val_loss: 0.1268 - val_accuracy: 0.8000
# Epoch 189/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0857 - accuracy: 0.8667 - val_loss: 0.1238 - val_accuracy: 0.8000
# Epoch 190/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.8667 - val_loss: 0.1210 - val_accuracy: 0.8000
# Epoch 191/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.8667 - val_loss: 0.1181 - val_accuracy: 0.8000
# Epoch 192/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.8889 - val_loss: 0.1153 - val_accuracy: 0.8000
# Epoch 193/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0784 - accuracy: 0.8889 - val_loss: 0.1125 - val_accuracy: 0.8000
# Epoch 194/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0766 - accuracy: 0.8889 - val_loss: 0.1097 - val_accuracy: 0.9000
# Epoch 195/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0749 - accuracy: 0.8889 - val_loss: 0.1070 - val_accuracy: 0.9000
# Epoch 196/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0733 - accuracy: 0.8889 - val_loss: 0.1043 - val_accuracy: 0.9000
# Epoch 197/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0717 - accuracy: 0.9000 - val_loss: 0.1016 - val_accuracy: 0.9000
# Epoch 198/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0703 - accuracy: 0.9000 - val_loss: 0.0993 - val_accuracy: 0.9000
# Epoch 199/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0689 - accuracy: 0.9000 - val_loss: 0.0970 - val_accuracy: 0.9000
# Epoch 200/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0676 - accuracy: 0.9111 - val_loss: 0.0947 - val_accuracy: 0.9000
# Epoch 201/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 0.9222 - val_loss: 0.0924 - val_accuracy: 0.9000
# Epoch 202/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9222 - val_loss: 0.0902 - val_accuracy: 0.9000
# Epoch 203/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9333 - val_loss: 0.0878 - val_accuracy: 0.9000
# Epoch 204/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0625 - accuracy: 0.9333 - val_loss: 0.0856 - val_accuracy: 0.9000
# Epoch 205/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0613 - accuracy: 0.9444 - val_loss: 0.0835 - val_accuracy: 0.9000
# Epoch 206/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0602 - accuracy: 0.9444 - val_loss: 0.0814 - val_accuracy: 0.9000
# Epoch 207/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 0.9444 - val_loss: 0.0793 - val_accuracy: 0.9000
# Epoch 208/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 0.9444 - val_loss: 0.0773 - val_accuracy: 0.9000
# Epoch 209/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0570 - accuracy: 0.9444 - val_loss: 0.0753 - val_accuracy: 0.9000
# Epoch 210/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9444 - val_loss: 0.0734 - val_accuracy: 1.0000
# Epoch 211/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0549 - accuracy: 0.9444 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 212/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0539 - accuracy: 0.9444 - val_loss: 0.0695 - val_accuracy: 1.0000
# Epoch 213/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 0.9444 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 214/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0521 - accuracy: 0.9444 - val_loss: 0.0663 - val_accuracy: 1.0000
# Epoch 215/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9444 - val_loss: 0.0647 - val_accuracy: 1.0000
# Epoch 216/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0505 - accuracy: 0.9444 - val_loss: 0.0632 - val_accuracy: 1.0000
# Epoch 217/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9444 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 218/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9444 - val_loss: 0.0603 - val_accuracy: 1.0000
# Epoch 219/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 0.9444 - val_loss: 0.0590 - val_accuracy: 1.0000
# Epoch 220/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9444 - val_loss: 0.0576 - val_accuracy: 1.0000
# Epoch 221/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0469 - accuracy: 0.9444 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 222/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0462 - accuracy: 0.9444 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 223/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 0.9444 - val_loss: 0.0537 - val_accuracy: 1.0000
# Epoch 224/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0450 - accuracy: 0.9444 - val_loss: 0.0526 - val_accuracy: 1.0000
# Epoch 225/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0444 - accuracy: 0.9444 - val_loss: 0.0515 - val_accuracy: 1.0000
# Epoch 226/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9444 - val_loss: 0.0505 - val_accuracy: 1.0000
# Epoch 227/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9444 - val_loss: 0.0494 - val_accuracy: 1.0000
# Epoch 228/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 0.9444 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 229/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.9444 - val_loss: 0.0475 - val_accuracy: 1.0000
# Epoch 230/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9333 - val_loss: 0.0466 - val_accuracy: 1.0000
# Epoch 231/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9333 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 232/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0409 - accuracy: 0.9333 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 233/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0405 - accuracy: 0.9333 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 234/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9333 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 235/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9333 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 236/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 0.9333 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 237/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9333 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 238/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0386 - accuracy: 0.9333 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 239/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 0.9333 - val_loss: 0.0396 - val_accuracy: 1.0000
# Epoch 240/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9333 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 241/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9333 - val_loss: 0.0383 - val_accuracy: 1.0000
# Epoch 242/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.9333 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 243/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 0.9333 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 244/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 0.9333 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 245/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9333 - val_loss: 0.0361 - val_accuracy: 1.0000
# Epoch 246/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0361 - accuracy: 0.9333 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 247/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0358 - accuracy: 0.9333 - val_loss: 0.0350 - val_accuracy: 1.0000
# Epoch 248/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0355 - accuracy: 0.9333 - val_loss: 0.0345 - val_accuracy: 1.0000
# Epoch 249/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0353 - accuracy: 0.9444 - val_loss: 0.0340 - val_accuracy: 1.0000
# Epoch 250/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9444 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 251/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 0.9444 - val_loss: 0.0331 - val_accuracy: 1.0000
# Epoch 252/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 0.9444 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 253/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 0.9556 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 254/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9556 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 255/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 0.9556 - val_loss: 0.0314 - val_accuracy: 1.0000
# Epoch 256/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9556 - val_loss: 0.0310 - val_accuracy: 1.0000
# Epoch 257/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9556 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 258/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 0.9556 - val_loss: 0.0302 - val_accuracy: 1.0000
# Epoch 259/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9556 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 260/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9556 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 261/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9556 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 262/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 0.9556 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 263/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 0.9556 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 264/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9556 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 265/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9556 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 266/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 0.9556 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 267/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9556 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 268/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0316 - accuracy: 0.9667 - val_loss: 0.0269 - val_accuracy: 1.0000
# Epoch 269/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9667 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 270/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9667 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 271/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9667 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 272/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9667 - val_loss: 0.0257 - val_accuracy: 1.0000
# Epoch 273/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9667 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 274/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 0.9667 - val_loss: 0.0252 - val_accuracy: 1.0000
# Epoch 275/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9667 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 276/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9667 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 277/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9667 - val_loss: 0.0244 - val_accuracy: 1.0000
# Epoch 278/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9667 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 279/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9667 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 280/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 0.9667 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 281/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 0.9667 - val_loss: 0.0234 - val_accuracy: 1.0000
# Epoch 282/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9667 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 283/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 0.9667 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 284/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0296 - accuracy: 0.9667 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 285/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0295 - accuracy: 0.9667 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 286/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 0.9667 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 287/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 0.9667 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 288/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9667 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 289/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.9667 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 290/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 0.9667 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 291/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 0.9667 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 292/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0287 - accuracy: 0.9667 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 293/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0287 - accuracy: 0.9667 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 294/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9778 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 295/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0284 - accuracy: 0.9889 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 296/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 0.9667 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 297/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0282 - accuracy: 0.9889 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 298/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0282 - accuracy: 0.9667 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 299/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.9889 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 300/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0280 - accuracy: 0.9889 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 301/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 0.9889 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 302/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0278 - accuracy: 0.9889 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 303/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0277 - accuracy: 0.9889 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 304/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 0.9889 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 305/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9889 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 306/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9889 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 307/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 0.9889 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 308/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9889 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 309/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0273 - accuracy: 0.9889 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 310/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 0.9889 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 311/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 0.9889 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 312/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9889 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 313/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9889 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 314/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9889 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 315/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9889 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 316/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0267 - accuracy: 0.9889 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 317/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9889 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 318/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9889 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 319/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9889 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 320/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9889 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 321/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9889 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 322/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9889 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 323/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9889 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 324/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9889 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 325/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9889 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 326/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0260 - accuracy: 0.9889 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 327/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 0.9889 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 328/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 0.9889 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 329/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0258 - accuracy: 0.9889 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 330/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 0.9889 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 331/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9889 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 332/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9889 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 333/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9889 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 334/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0255 - accuracy: 0.9889 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 335/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 0.9889 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 336/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9889 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 337/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9889 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 338/1000
# ...
# Epoch 927/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9889 - val_loss: 3.5208e-04 - val_accuracy: 1.0000
# Epoch 928/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9889 - val_loss: 3.5030e-04 - val_accuracy: 1.0000
# Epoch 929/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9889 - val_loss: 3.4887e-04 - val_accuracy: 1.0000
# Epoch 930/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9889 - val_loss: 3.4751e-04 - val_accuracy: 1.0000
# Epoch 931/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9889 - val_loss: 3.4576e-04 - val_accuracy: 1.0000
# Epoch 932/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9889 - val_loss: 3.4350e-04 - val_accuracy: 1.0000
# Epoch 933/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.4152e-04 - val_accuracy: 1.0000
# Epoch 934/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.3961e-04 - val_accuracy: 1.0000
# Epoch 935/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.3782e-04 - val_accuracy: 1.0000
# Epoch 936/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.3590e-04 - val_accuracy: 1.0000
# Epoch 937/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.3384e-04 - val_accuracy: 1.0000
# Epoch 938/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.3164e-04 - val_accuracy: 1.0000
# Epoch 939/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.2942e-04 - val_accuracy: 1.0000
# Epoch 940/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.2733e-04 - val_accuracy: 1.0000
# Epoch 941/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.2515e-04 - val_accuracy: 1.0000
# Epoch 942/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.2327e-04 - val_accuracy: 1.0000
# Epoch 943/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.2151e-04 - val_accuracy: 1.0000
# Epoch 944/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.1970e-04 - val_accuracy: 1.0000
# Epoch 945/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9889 - val_loss: 3.1785e-04 - val_accuracy: 1.0000
# Epoch 946/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.1564e-04 - val_accuracy: 1.0000
# Epoch 947/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.1375e-04 - val_accuracy: 1.0000
# Epoch 948/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.1207e-04 - val_accuracy: 1.0000
# Epoch 949/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.1015e-04 - val_accuracy: 1.0000
# Epoch 950/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.0871e-04 - val_accuracy: 1.0000
# Epoch 951/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.0701e-04 - val_accuracy: 1.0000
# Epoch 952/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.0544e-04 - val_accuracy: 1.0000
# Epoch 953/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.0385e-04 - val_accuracy: 1.0000
# Epoch 954/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.0200e-04 - val_accuracy: 1.0000
# Epoch 955/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 3.0013e-04 - val_accuracy: 1.0000
# Epoch 956/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 2.9830e-04 - val_accuracy: 1.0000
# Epoch 957/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 2.9623e-04 - val_accuracy: 1.0000
# Epoch 958/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9889 - val_loss: 2.9435e-04 - val_accuracy: 1.0000
# Epoch 959/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.9235e-04 - val_accuracy: 1.0000
# Epoch 960/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.9067e-04 - val_accuracy: 1.0000
# Epoch 961/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.8900e-04 - val_accuracy: 1.0000
# Epoch 962/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.8735e-04 - val_accuracy: 1.0000
# Epoch 963/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.8586e-04 - val_accuracy: 1.0000
# Epoch 964/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.8425e-04 - val_accuracy: 1.0000
# Epoch 965/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.8252e-04 - val_accuracy: 1.0000
# Epoch 966/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.8074e-04 - val_accuracy: 1.0000
# Epoch 967/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.7927e-04 - val_accuracy: 1.0000
# Epoch 968/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.7760e-04 - val_accuracy: 1.0000
# Epoch 969/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.7588e-04 - val_accuracy: 1.0000
# Epoch 970/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.7462e-04 - val_accuracy: 1.0000
# Epoch 971/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.7298e-04 - val_accuracy: 1.0000
# Epoch 972/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9889 - val_loss: 2.7117e-04 - val_accuracy: 1.0000
# Epoch 973/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.6979e-04 - val_accuracy: 1.0000
# Epoch 974/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.6846e-04 - val_accuracy: 1.0000
# Epoch 975/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.6676e-04 - val_accuracy: 1.0000
# Epoch 976/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.6529e-04 - val_accuracy: 1.0000
# Epoch 977/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.6365e-04 - val_accuracy: 1.0000
# Epoch 978/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.6204e-04 - val_accuracy: 1.0000
# Epoch 979/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.6048e-04 - val_accuracy: 1.0000
# Epoch 980/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.5928e-04 - val_accuracy: 1.0000
# Epoch 981/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.5777e-04 - val_accuracy: 1.0000
# Epoch 982/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.5626e-04 - val_accuracy: 1.0000
# Epoch 983/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.5459e-04 - val_accuracy: 1.0000
# Epoch 984/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9889 - val_loss: 2.5348e-04 - val_accuracy: 1.0000
# Epoch 985/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.5228e-04 - val_accuracy: 1.0000
# Epoch 986/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.5091e-04 - val_accuracy: 1.0000
# Epoch 987/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.4938e-04 - val_accuracy: 1.0000
# Epoch 988/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.4809e-04 - val_accuracy: 1.0000
# Epoch 989/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.4689e-04 - val_accuracy: 1.0000
# Epoch 990/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.4586e-04 - val_accuracy: 1.0000
# Epoch 991/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.4454e-04 - val_accuracy: 1.0000
# Epoch 992/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.4306e-04 - val_accuracy: 1.0000
# Epoch 993/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.4157e-04 - val_accuracy: 1.0000
# Epoch 994/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.3997e-04 - val_accuracy: 1.0000
# Epoch 995/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.3850e-04 - val_accuracy: 1.0000
# Epoch 996/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9889 - val_loss: 2.3712e-04 - val_accuracy: 1.0000
# Epoch 997/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.3585e-04 - val_accuracy: 1.0000
# Epoch 998/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9889 - val_loss: 2.3469e-04 - val_accuracy: 1.0000
# Epoch 999/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9889 - val_loss: 2.3313e-04 - val_accuracy: 1.0000
# Epoch 1000/1000
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9889 - val_loss: 2.3160e-04 - val_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'root_mean_squared_error'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb Cell 20 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> # Invoke the functions.
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a> my_model = build_model(learning_rate)
# ---> <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=10'>11</a> weight, bias, epochs, rmse, history = train_model(my_model,
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a>                                         shuffled_train_df.drop('status', axis=1),
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a>                                         shuffled_train_df[['status']],
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=13'>14</a>                                         epochs, batch_size)
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=15'>16</a> plot_the_loss_curve(epochs, history["root_mean_squared_error"],
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a>                     history["val_root_mean_squared_error"])
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=18'>19</a> # print(weight)
#
# /Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb Cell 20 in train_model(model, x, y, my_epochs, my_batch_size, my_validation_split)
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=37'>38</a> # Isolate the root mean squared error for each epoch.
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=38'>39</a> hist = pd.DataFrame(history.history)
# ---> <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=39'>40</a> rmse = hist["root_mean_squared_error"]
#      <a href='vscode-notebook-cell:/Users/shomeier/dev/git/my/sho-playground/machine-learning/feature-crosses/feature-cross-simple-example.ipynb#X25sZmlsZQ%3D%3D?line=41'>42</a> return trained_weight, trained_bias, epochs, rmse, history.history
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'root_mean_squared_error'

# %% [markdown]
# ## Prediction

# %%
# A few random samples
should_be_healthy = [2., 2.2]
should_be_sick = [2., -1.2]

# Convert into Numpy array
samples_to_predict = np.array([should_be_healthy, should_be_sick])
print(samples_to_predict.shape)

predict = my_model.predict(x=samples_to_predict)
print(predict)
# Out:
# (2, 2)
# 1/1 [==============================] - 0s 67ms/step
# [[6.4787776e-07]
#  [9.9974835e-01]]

# %% [markdown]
# ## Non-Linear Problem

# %% [markdown]
# Create the sample data set
#
# Scale and shift the (0, 1) range from np.random.random to (-5, 5).
#
# See also here: https://stackoverflow.com/questions/59389241/how-to-generate-a-random-float-in-range-1-1-using-numpy-random-rand

# %%
N = 100
max_val, min_val = 5, -5
range_size = (max_val - min_val)  # 2
x = np.random.random([N]) * range_size + min_val
y = np.random.random([N]) * range_size + min_val

# %%
plt.figure(figsize=(10, 8))

plt.scatter(x, y)

plt.xlabel('x') 
plt.ylabel('y') 

plt.title("Training Data") 
plt.show()
